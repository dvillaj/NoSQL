# %%
# %load_ext imongo

# %%
# %mongo_connect
# Out:
# MongoClient('127.0.0.1', 27017)

# %%
# %show_dbs
# Out:
# Pymongo> MongoClient(url).database_names()
# [u'local']

# %%
# %show_collections local
# Out:
# Pymongo> Database(MongoClient('127.0.0.1', 27017), local).collection_names()
# [u'startup_log', u'system.indexes']

# %%
con = %mongo_connect

# %%
help(con)
# Out:
# Help on MongoClient in module pymongo.mongo_client object:
#
# class MongoClient(pymongo.common.BaseObject)
#  |  Method resolution order:
#  |      MongoClient
#  |      pymongo.common.BaseObject
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self)
#  |
#  |  __eq__(self, other)
#  |
#  |  __exit__(self, exc_type, exc_val, exc_tb)
#  |
#  |  __getattr__(self, name)
#  |      Get a database by name.
#  |
#  |      Raises :class:`~pymongo.errors.InvalidName` if an invalid
#  |      database name is used.
#  |
#  |      :Parameters:
#  |        - `name`: the name of the database to get
#  |
#  |  __getitem__(self, name)
#  |      Get a database by name.
#  |
#  |      Raises :class:`~pymongo.errors.InvalidName` if an invalid
#  |      database name is used.
#  |
#  |      :Parameters:
#  |        - `name`: the name of the database to get
#  |
# ...

# %%
# %insert test.test {"test": "test1"}

# %%
con.test.test.find_one()
# Out:
# {u'_id': ObjectId('5617c250801d3209558b76c6'), u'test': u'test1'}

# %%
# %drop test.test

# %%
# %drop test

# %%
# %insert test.test {"test": "test1"}

# %%
# %find test.test {"test": "test1"}
# Out:
# [{u'_id': ObjectId('5617c28b801d3209558b76c7'),
#   u'test': u'test1'}]

# %%
# %drop test.test
# %drop test
