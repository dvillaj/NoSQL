# %%
import json
import pandas as pd
#import matplotlib.pyplot as plt

# %%
tweets_data_path = './data/tweets.txt'

tweets_data = []
tweets_file = open(tweets_data_path, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

print len(tweets_data)
# Out:
# 1960

# %%
import json

print json.dumps(tweets_data[1], indent=4)
# Out:
# {
#     "contributors": null,
#     "truncated": false,
#     "text": "RT @bsindia: After Infosys' stellar show, TCS lacks spark\nhttp://t.co/nWK351lhHX http://t.co/PTMGxYHYTq",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "id": 654147558495784960,
#     "favorite_count": 0,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "timestamp_ms": "1444795906076",
#     "entities": {
#         "user_mentions": [
#             {
#                 "id": 43855487,
#                 "indices": [
#                     3,
#                     11
#                 ],
#                 "id_str": "43855487",
#                 "screen_name": "bsindia",
#                 "name": "Business Standard"
#             }
#         ],
#         "symbols": [],
#         "hashtags": [],
#         "urls": [
#             {
#                 "url": "http://t.co/nWK351lhHX",
#                 "indices": [
#                     58,
#                     80
#                 ],
#                 "expanded_url": "http://mybs.in/2S1Gp7Z",
#                 "display_url": "mybs.in/2S1Gp7Z"
#             }
#         ],
#         "media": [
#             {
#                 "source_user_id": 43855487,
#                 "source_status_id_str": "654147136804667398",
#                 "expanded_url": "http://twitter.com/bsindia/status/654147136804667398/photo/1",
#                 "display_url": "pic.twitter.com/PTMGxYHYTq",
#                 "url": "http://t.co/PTMGxYHYTq",
#                 "media_url_https": "https://pbs.twimg.com/media/CRP-sl_VAAAlrlA.jpg",
#                 "source_user_id_str": "43855487",
#                 "source_status_id": 654147136804667398,
#                 "id_str": "654146412964282368",
#                 "sizes": {
#                     "small": {
#                         "h": 254,
#                         "resize": "fit",
#                         "w": 340
#                     },
#                     "large": {
#                         "h": 464,
#                         "resize": "fit",
#                         "w": 620
#                     },
#                     "medium": {
#                         "h": 449,
#                         "resize": "fit",
#                         "w": 600
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "indices": [
#                     81,
#                     103
#                 ],
#                 "type": "photo",
#                 "id": 654146412964282368,
#                 "media_url": "http://pbs.twimg.com/media/CRP-sl_VAAAlrlA.jpg"
#             }
#         ]
#     },
#     "in_reply_to_screen_name": null,
#     "id_str": "654147558495784960",
#     "retweet_count": 0,
#     "in_reply_to_user_id": null,
#     "favorited": false,
#     "retweeted_status": {
#         "contributors": null,
#         "truncated": false,
#         "text": "After Infosys' stellar show, TCS lacks spark\nhttp://t.co/nWK351lhHX http://t.co/PTMGxYHYTq",
#         "is_quote_status": false,
#         "in_reply_to_status_id": null,
#         "id": 654147136804667398,
#         "favorite_count": 0,
#         "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#         "retweeted": false,
#         "coordinates": null,
#         "entities": {
#             "user_mentions": [],
#             "symbols": [],
#             "hashtags": [],
#             "urls": [
#                 {
#                     "url": "http://t.co/nWK351lhHX",
#                     "indices": [
#                         45,
#                         67
#                     ],
#                     "expanded_url": "http://mybs.in/2S1Gp7Z",
#                     "display_url": "mybs.in/2S1Gp7Z"
#                 }
#             ],
#             "media": [
#                 {
#                     "expanded_url": "http://twitter.com/bsindia/status/654147136804667398/photo/1",
#                     "display_url": "pic.twitter.com/PTMGxYHYTq",
#                     "url": "http://t.co/PTMGxYHYTq",
#                     "media_url_https": "https://pbs.twimg.com/media/CRP-sl_VAAAlrlA.jpg",
#                     "id_str": "654146412964282368",
#                     "sizes": {
#                         "small": {
#                             "h": 254,
#                             "resize": "fit",
#                             "w": 340
#                         },
#                         "large": {
#                             "h": 464,
#                             "resize": "fit",
#                             "w": 620
#                         },
#                         "medium": {
#                             "h": 449,
#                             "resize": "fit",
#                             "w": 600
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "indices": [
#                         68,
#                         90
#                     ],
#                     "type": "photo",
#                     "id": 654146412964282368,
#                     "media_url": "http://pbs.twimg.com/media/CRP-sl_VAAAlrlA.jpg"
#                 }
#             ]
#         },
#         "in_reply_to_screen_name": null,
#         "id_str": "654147136804667398",
#         "retweet_count": 1,
#         "in_reply_to_user_id": null,
#         "favorited": false,
#         "user": {
#             "follow_request_sent": null,
#             "profile_use_background_image": true,
#             "default_profile_image": false,
#             "id": 43855487,
#             "verified": true,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/2881526894/1a54fd9ccb222e586c2ed3127482c405_normal.jpeg",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "000000",
#             "followers_count": 191797,
#             "profile_sidebar_border_color": "CECECE",
#             "id_str": "43855487",
#             "profile_background_color": "9AE4E8",
#             "listed_count": 1465,
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/16584992/bs_twitter_bg.jpg",
#             "utc_offset": 19800,
#             "statuses_count": 96846,
#             "description": "Breaking news on economy, companies, markets and incisive analysis from India's leading business daily",
#             "friends_count": 339,
#             "location": "India",
#             "profile_link_color": "AC151A",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/2881526894/1a54fd9ccb222e586c2ed3127482c405_normal.jpeg",
#             "following": null,
#             "geo_enabled": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/43855487/1444202373",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/16584992/bs_twitter_bg.jpg",
#             "name": "Business Standard",
#             "lang": "en",
#             "profile_background_tile": false,
#             "favourites_count": 23,
#             "screen_name": "bsindia",
#             "notifications": null,
#             "url": "http://www.business-standard.com",
#             "created_at": "Mon Jun 01 08:52:08 +0000 2009",
#             "contributors_enabled": false,
#             "time_zone": "New Delhi",
#             "protected": false,
#             "default_profile": false,
#             "is_translator": false
#         },
#         "geo": null,
#         "in_reply_to_user_id_str": null,
#         "possibly_sensitive": false,
#         "lang": "en",
#         "created_at": "Wed Oct 14 04:10:05 +0000 2015",
#         "filter_level": "low",
#         "in_reply_to_status_id_str": null,
#         "place": null,
#         "extended_entities": {
#             "media": [
#                 {
#                     "expanded_url": "http://twitter.com/bsindia/status/654147136804667398/photo/1",
#                     "display_url": "pic.twitter.com/PTMGxYHYTq",
#                     "url": "http://t.co/PTMGxYHYTq",
#                     "media_url_https": "https://pbs.twimg.com/media/CRP-sl_VAAAlrlA.jpg",
#                     "id_str": "654146412964282368",
#                     "sizes": {
#                         "small": {
#                             "h": 254,
#                             "resize": "fit",
#                             "w": 340
#                         },
#                         "large": {
#                             "h": 464,
#                             "resize": "fit",
#                             "w": 620
#                         },
#                         "medium": {
#                             "h": 449,
#                             "resize": "fit",
#                             "w": 600
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "indices": [
#                         68,
#                         90
#                     ],
#                     "type": "photo",
#                     "id": 654146412964282368,
#                     "media_url": "http://pbs.twimg.com/media/CRP-sl_VAAAlrlA.jpg"
#                 }
#             ]
#         }
#     },
#     "user": {
#         "follow_request_sent": null,
#         "profile_use_background_image": true,
#         "default_profile_image": false,
#         "id": 365345639,
#         "verified": false,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1521848538/onedotin-logo-twitter_normal.jpg",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "followers_count": 2025,
#         "profile_sidebar_border_color": "C0DEED",
#         "id_str": "365345639",
#         "profile_background_color": "C0DEED",
#         "listed_count": 59,
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "utc_offset": 19800,
#         "statuses_count": 35304,
#         "description": "We collate interesting news for Indians from various sources. Also see @60secondsnow. Cover photo: International Yoga Day at Rajpath, Delhi",
#         "friends_count": 1279,
#         "location": "Bengaluru",
#         "profile_link_color": "0084B4",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1521848538/onedotin-logo-twitter_normal.jpg",
#         "following": null,
#         "geo_enabled": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/365345639/1434873890",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "name": "One.in",
#         "lang": "en",
#         "profile_background_tile": false,
#         "favourites_count": 82,
#         "screen_name": "Onedotin",
#         "notifications": null,
#         "url": "http://one.in",
#         "created_at": "Wed Aug 31 08:37:50 +0000 2011",
#         "contributors_enabled": false,
#         "time_zone": "New Delhi",
#         "protected": false,
#         "default_profile": true,
#         "is_translator": false
#     },
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "possibly_sensitive": false,
#     "lang": "en",
#     "created_at": "Wed Oct 14 04:11:46 +0000 2015",
#     "filter_level": "low",
#     "in_reply_to_status_id_str": null,
#     "place": null,
#     "extended_entities": {
#         "media": [
#             {
#                 "source_user_id": 43855487,
#                 "source_status_id_str": "654147136804667398",
#                 "expanded_url": "http://twitter.com/bsindia/status/654147136804667398/photo/1",
#                 "display_url": "pic.twitter.com/PTMGxYHYTq",
#                 "url": "http://t.co/PTMGxYHYTq",
#                 "media_url_https": "https://pbs.twimg.com/media/CRP-sl_VAAAlrlA.jpg",
#                 "source_user_id_str": "43855487",
#                 "source_status_id": 654147136804667398,
#                 "id_str": "654146412964282368",
#                 "sizes": {
#                     "small": {
#                         "h": 254,
#                         "resize": "fit",
#                         "w": 340
#                     },
#                     "large": {
#                         "h": 464,
#                         "resize": "fit",
#                         "w": 620
#                     },
#                     "medium": {
#                         "h": 449,
#                         "resize": "fit",
#                         "w": 600
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "indices": [
#                     81,
#                     103
#                 ],
#                 "type": "photo",
#                 "id": 654146412964282368,
#                 "media_url": "http://pbs.twimg.com/media/CRP-sl_VAAAlrlA.jpg"
#             }
#         ]
#     }
# }

# %%
tweets = pd.DataFrame()

tweets['text'] = map(lambda tweet: tweet['text'], tweets_data)
tweets['lang'] = map(lambda tweet: tweet['lang'], tweets_data)
tweets['country'] = map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data)

tweets_by_lang = tweets['lang'].value_counts()

print tweets_by_lang
# Out:
# en     1299
# ja      236
# in      196
# tl       84
# fr       26
# de       21
# und      20
# es       14
# da       11
# pt       11
# it        9
# pl        5
# ru        4
# ko        4
# sv        4
# nl        3
# zh        2
# no        2
# tr        2
# sl        2
# et        1
# hu        1
# ta        1
# th        1
# sk        1
# Name: lang, dtype: int64
